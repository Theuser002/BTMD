# %%
import sys
sys.path.append('/media/data/hungnt/work/Datasets/BTMD/Code/src')

import os
import numpy as np
import torch
import config
import pandas as pd
import pyreadr

# %%
cfg = config.config_dict
TEST_CSV_DIR = cfg['TEST_CSV_DIR']
test_csv_path = os.path.join(cfg['TEST_CSV_DIR'], '1.1_test.csv')

# %%
print(test_csv_path)
# Out:
# /media/data/hungnt/work/Datasets/BTMD/Dataset/csv/test/1.1_test.csv

# %%
df_test = pd.read_csv(test_csv_path, index_col = 0).fillna(0)

# %%
df_test
# Out:
#                      cg22054918  cg16476975  cg03940848  cg25570913  \
# 5684819014_R03C02      0.947269    0.008453    0.123884    0.963694
# 5684819013_R05C01      0.702404    0.117175    0.377721    0.903756
# 5911815023_R02C01      0.030544    0.936998    0.761774    0.025878
# 5911815023_R05C01      0.007512    0.506859    0.022470    0.020558
# 6969568005_R05C01      0.044909    0.068658    0.037619    0.610629
# ...                         ...         ...         ...         ...
# 3998523002_R03C02      0.039866    0.932913    0.852365    0.006970
# 3998523019_R05C02      0.076750    0.000000    0.103245    0.268817
# 3998523022_R02C01      0.035191    0.031050    0.057630    0.003892
# 3998568167_R05C01      0.026809    0.861096    0.568622    0.126849
# 200091640051_R03C01    0.290089    0.984556    0.881207    0.762752
#
#                      cg02809746  cg01517680  cg04110886  cg05649108  \
# 5684819014_R03C02      0.494731    0.028322    0.055772    0.038964
# ...

# %%
test_features = np.array(df_test.iloc[:,:-1])
test_labels = np.array(df_test.iloc[:,-1])

# %%
test_features, test_labels
# Out:
# (array([[0.94726853, 0.00845275, 0.12388393, ..., 0.        , 0.3486616 ,
#          0.72370946],
#         [0.70240445, 0.11717529, 0.3777208 , ..., 0.0090631 , 0.16833694,
#          0.37038961],
#         [0.03054415, 0.93699793, 0.76177423, ..., 0.58084483, 0.30662325,
#          0.55203575],
#         ...,
#         [0.03519062, 0.03104953, 0.05763021, ..., 0.25895131, 0.09624576,
#          0.13365829],
#         [0.02680915, 0.86109556, 0.56862172, ..., 0.02650736, 0.44171506,
#          0.6368363 ],
#         [0.29008864, 0.98455551, 0.8812074 , ..., 0.1077976 , 0.06855332,
#          0.24725633]]),
#  array(['GBM, G34', 'GBM, G34', 'CONTR, CEBM', 'CONTR, CEBM', 'LGG, PA PF',
#         'LGG, PA MID', 'LGG, PA PF', 'ATRT, SHH', 'CONTR, REACT',
#         'LGG, PA MID', 'MB, WNT', 'MB, SHH CHL AD', 'MB, SHH INF',
#         'MB, G4', 'ATRT, TYR', 'ATRT, SHH', 'LGG, PA PF', 'LGG, PA PF',
#         'EPN, RELA', 'MB, G4', 'MB, G3', 'EPN, PF A', 'EPN, RELA', 'ETMR',
# ...
