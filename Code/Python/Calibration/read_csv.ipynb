# %%
import os
import numpy as np
import sys
import torch
sys.path.append('../')
import config
import pandas as pd
import pyreadr

# %%
cfg = config.config_dict
test_csv_path = os.path.join(cfg['TRAIN_CSV_DIR'], '1.0_train.csv')

# %%
print(test_csv_path)
# Out:
# /media/data/hungnt/work/Datasets/BTMD/Dataset/csv/train/1.0_train.csv

# %%
df = pd.read_csv(test_csv_path, index_col = 0).fillna(0)

# %%
df
# Out:
#                      cg22054918  cg16476975  cg03940848  cg25570913  \
# 5684819014_R03C02      0.947269    0.008453    0.123884    0.963694
# 5684819014_R05C02      0.719027    0.067590    0.000000    0.885362
# 5684819014_R06C02      0.986904    0.000000    0.038046    1.000000
# 5684819013_R05C02      0.163068    0.231008    0.000000    0.947795
# 5684819014_R03C01      0.972470    0.119748    0.008277    0.984159
# ...                         ...         ...         ...         ...
# 200091640051_R03C02    0.109991    0.967823    0.849322    0.634747
# 200078650174_R03C01    0.346423    0.764030    0.429026    0.000000
# 200275560098_R02C02    0.196767    0.902402    0.089633    0.950487
# 200275560113_R05C02    0.145792    0.514398    0.032532    0.676764
# 200277210073_R05C01    0.345995    0.896384    0.265516    0.878837
#
#                      cg02809746  cg01517680  cg04110886  cg18222083  \
# 5684819014_R03C02      0.494731    0.028322    0.055772    0.014548
# ...

# %%
features = np.array(df.iloc[:,:-1])
labels = np.array(df.iloc[:,-1])

# %%
features, labels
# Out:
# (array([[0.94726853, 0.00845275, 0.12388393, ..., 0.88807406, 0.67923516,
#          0.18746042],
#         [0.71902693, 0.06758958, 0.        , ..., 0.72042347, 0.81276591,
#          0.99119655],
#         [0.98690354, 0.        , 0.03804632, ..., 0.9110447 , 0.84444445,
#          0.94415831],
#         ...,
#         [0.19676739, 0.90240215, 0.08963326, ..., 0.74074331, 0.88092304,
#          0.98082415],
#         [0.14579247, 0.51439754, 0.03253205, ..., 0.62448143, 0.85841071,
#          1.        ],
#         [0.34599483, 0.89638363, 0.2655162 , ..., 0.68007837, 0.7530381 ,
#          0.89563397]]),
#  array(['GBM, G34', 'DMG, K27', 'DMG, K27', ..., 'ANA PA', 'ANA PA',
#         'ANA PA'], dtype=object))

# %%
print(features.shape)
# Out:
# (2204, 10000)
