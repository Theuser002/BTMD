# %%
import os
import sys
sys.path.append('../')
import pyreadr

# %%
RData = '/media/data/hungnt/work/Datasets/BTMD/Dataset/Anno/anno.RData'
df = pyreadr.read_r(RData)
df['anno']
# Out:
#                                                 title geo_accession  \
# rownames
# GSM2402854         GBM, G34, sample 1 [reference set]    GSM2402854
# GSM2402855         DMG, K27, sample 2 [reference set]    GSM2402855
# GSM2402856         DMG, K27, sample 3 [reference set]    GSM2402856
# GSM2402857         DMG, K27, sample 4 [reference set]    GSM2402857
# GSM2402858         DMG, K27, sample 5 [reference set]    GSM2402858
# ...                                               ...           ...
# GSM2405653  PIN T,  PB A, sample 2797 [reference set]    GSM2405653
# GSM2405654        ANA PA, sample 2798 [reference set]    GSM2405654
# GSM2405655        ANA PA, sample 2799 [reference set]    GSM2405655
# GSM2405656        ANA PA, sample 2800 [reference set]    GSM2405656
# GSM2405657        ANA PA, sample 2801 [reference set]    GSM2405657
#
#                            status submission_date last_update_date     type  \
# rownames
# ...
