# %%
import pandas as pd
import sys
sys.path.append('../Python/')

# %%
csv_path = '/media/data/hungnt/work/Datasets/BTMD/Dataset/csv/train/1.0_train.csv'
df = pd.read_csv(csv_path)
print(df)
# Out:
#                Unnamed: 0  cg22054918  cg16476975  cg03940848  cg25570913  \
# 0       5684819014_R03C02    0.947269    0.008453    0.123884    0.963694
# 1       5684819014_R05C02    0.719027    0.067590    0.000000    0.885362
# 2       5684819014_R06C02    0.986904    0.000000    0.038046    1.000000
# 3       5684819013_R05C02    0.163068    0.231008    0.000000    0.947795
# 4       5684819014_R03C01    0.972470    0.119748    0.008277    0.984159
# ...                   ...         ...         ...         ...         ...
# 2199  200091640051_R03C02    0.109991    0.967823    0.849322    0.634747
# 2200  200078650174_R03C01    0.346423    0.764030    0.429026    0.000000
# 2201  200275560098_R02C02    0.196767    0.902402    0.089633    0.950487
# 2202  200275560113_R05C02    0.145792    0.514398    0.032532    0.676764
# 2203  200277210073_R05C01    0.345995    0.896384    0.265516    0.878837
#
#       cg02809746  cg01517680  cg04110886  cg18222083  cg05649108  ...  \
# ...
